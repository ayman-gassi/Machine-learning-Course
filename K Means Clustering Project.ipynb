# %% [markdown]
# # Projet K Means Clustering
# Pour ce projet, nous tenterons d’utiliser KMeans Clustering pour regrouper les universités en deux groupes, privé et public.
#
# ___
# Il est **très important de noter que nous avons en fait les étiquettes pour cet ensemble de données, mais nous ne les utiliserons PAS pour l’algorithme de clustering KMeans, car c’est un algorithme d’apprentissage non supervisé.**
#
# Lorsque vous utilisez l’algorithme Kmeans dans des circonstances normales, c’est parce que vous n’avez pas d’étiquettes. Dans ce cas-ci, nous utiliserons les étiquettes pour essayer d’avoir une idée de la façon dont l’algorithme s’est bien comporté, mais vous ne le ferez généralement pas pour Kmeans, donc le rapport de classification et la matrice de confusion à la fin de ce projet n’ont pas vraiment de sens dans un contexte réel.
# ___
#
# ## Les données
#
# Nous utiliserons une base de données avec 777 observations sur les 18 variables suivantes.
# * Facteur A privé avec niveaux Non et Oui indiquant université privée ou publique
# * Applications Nombre de demandes reçues
# * Accepter Nombre de demandes acceptées
# * Enrol Nombre de nouveaux étudiants inscrits
# * Top10perc Pct. nouveaux étudiants du top 10% de la classe H.S.
# * Top25perc Pct. nouveaux étudiants du top 25% de la classe H.S.
# * F.Undergrad Nombre d’étudiants à temps plein
# * P.Undergrad Nombre d’étudiants à temps partiel
# * Enseignement à l’étranger
# * Room.Board Frais de chambre et de pension
# * Livres Coût estimatif des livres
# * Dépenses personnelles estimées
# * Doctorat Pct. de la faculté avec Ph.D.
# * Terminal Pct. de la faculté avec diplôme terminal
# * S.F.Ratio Ratio étudiants/professeurs
# * perc.alumni Pct. alumni qui font un don
# * Dépenses d’enseignement par élève
# * Taux d’obtention du diplôme

# %% [markdown]
# ## Importer des bibliothèques
#
# **Importez les bibliothèques que vous utilisez habituellement pour l’analyse des données.**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, confusion_matrix

# %% [markdown]
# ## Get the Data

# %% [markdown]
# ## Obtenir les données

# %% [markdown]
# **Lire le fichier College_Data à l’aide de read_csv. Déterminer comment définir la première colonne comme index.**

# %%
df = pd.read_csv('docs/College_Data', index_col=0)

# %% [markdown]
# **Check the head of the data**

# %% [markdown]
# **Vérifier la tête des données**

# %%
df.head()
# Out:
#                              Private  Apps  Accept  Enroll  Top10perc  \
# Abilene Christian University     Yes  1660    1232     721         23
# Adelphi University               Yes  2186    1924     512         16
# Adrian College                   Yes  1428    1097     336         22
# Agnes Scott College              Yes   417     349     137         60
# Alaska Pacific University        Yes   193     146      55         16
#
#                               Top25perc  F.Undergrad  P.Undergrad  Outstate  \
# Abilene Christian University         52         2885          537      7440
# Adelphi University                   29         2683         1227     12280
# Adrian College                       50         1036           99     11250
# Agnes Scott College                  89          510           63     12960
# Alaska Pacific University            44          249          869      7560
#
#                               Room.Board  Books  Personal  PhD  Terminal  \
# ...

# %% [markdown]
# **Vérifier les méthodes info() et describe() sur les données.**

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 777 entries, Abilene Christian University to York College of Pennsylvania
# Data columns (total 18 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Private      777 non-null    object
#  1   Apps         777 non-null    int64
#  2   Accept       777 non-null    int64
#  3   Enroll       777 non-null    int64
#  4   Top10perc    777 non-null    int64
#  5   Top25perc    777 non-null    int64
#  6   F.Undergrad  777 non-null    int64
#  7   P.Undergrad  777 non-null    int64
#  8   Outstate     777 non-null    int64
#  9   Room.Board   777 non-null    int64
#  10  Books        777 non-null    int64
#  11  Personal     777 non-null    int64
#  12  PhD          777 non-null    int64
#  13  Terminal     777 non-null    int64
#  14  S.F.Ratio    777 non-null    float64
#  15  perc.alumni  777 non-null    int64
#  16  Expend       777 non-null    int64
# ...

# %%
# Out:
#                Apps        Accept       Enroll   Top10perc   Top25perc  \
# count    777.000000    777.000000   777.000000  777.000000  777.000000
# mean    3001.638353   2018.804376   779.972973   27.558559   55.796654
# std     3870.201484   2451.113971   929.176190   17.640364   19.804778
# min       81.000000     72.000000    35.000000    1.000000    9.000000
# 25%      776.000000    604.000000   242.000000   15.000000   41.000000
# 50%     1558.000000   1110.000000   434.000000   23.000000   54.000000
# 75%     3624.000000   2424.000000   902.000000   35.000000   69.000000
# max    48094.000000  26330.000000  6392.000000   96.000000  100.000000
#
#         F.Undergrad   P.Undergrad      Outstate   Room.Board        Books  \
# count    777.000000    777.000000    777.000000   777.000000   777.000000
# mean    3699.907336    855.298584  10440.669241  4357.526384   549.380952
# std     4850.420531   1522.431887   4023.016484  1096.696416   165.105360
# ...

# %% [markdown]
# ## EDA
#
# Il est temps de créer des visualisations de données !
#
# **Créer un diagramme de dispersion de Grad.Rate par rapport à Room.Board où les points sont colorés par la colonne Private.**

# %%
sns.scatterplot(x='Room.Board', y='Grad.Rate', hue='Private', data=df)
plt.title('Grad.Rate vs Room.Board colored by Private')
plt.show()

# %% [markdown]
# **Créer un diagramme de dispersion de F. Undergrad versus Outstate où les points sont colorés par la colonne Private.**

# %%
sns.scatterplot(x='Outstate', y='F.Undergrad', hue='Private', data=df)
plt.title('F.Undergrad vs Outstate colored by Private')
plt.show()

# %% [markdown]
# **Créer un histogramme empilé montrant les frais de scolarité hors de l’état en fonction de la colonne Privé. Essayez d’utiliser [sns.FacetGrid] (https://stanford.edu/~mwaskom/software/seaborn/generated/seaborn.FacetGrid.html). Si c’est trop compliqué, voyez si vous pouvez le faire en utilisant deux instances de pandas.plot(kind='hist').**

# %% [markdown]
# **Créer un histogramme similaire pour la colonne Grad.Rate.**

# %% [markdown]
# **Notez qu’il semble y avoir une école privée avec un taux d’obtention du diplôme supérieur à 100 %. Quel est le nom de cette école?**

# %%
# Out:
#                   Private  Apps  Accept  Enroll  Top10perc  Top25perc  \
# Cazenovia College     Yes  3847    3433     527          9         35
#
#                    F.Undergrad  P.Undergrad  Outstate  Room.Board  Books  \
# Cazenovia College         1010           12      9384        4840    600
#
#                    Personal  PhD  Terminal  S.F.Ratio  perc.alumni  Expend  \
# Cazenovia College       500   22        47       14.3           20    7697
#
#                    Grad.Rate
# Cazenovia College        118

# %% [markdown]
# **Définissez le taux d’obtention du diplôme de cette école à 100, pour que cela soit logique. Vous pouvez recevoir un avertissement et non une erreur) lorsque vous effectuez cette opération, utilisez donc des opérations de dataframe ou refaites simplement la visualisation de l’histogramme pour vous assurer qu’elle a bien été effectuée.**

# %%
# Out:
# /Users/marci/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
# Out:
# Empty DataFrame
# Columns: [Private, Apps, Accept, Enroll, Top10perc, Top25perc, F.Undergrad, P.Undergrad, Outstate, Room.Board, Books, Personal, PhD, Terminal, S.F.Ratio, perc.alumni, Expend, Grad.Rate]
# Index: []

# %% [markdown]
# ## K signifie création de grappe
#
# Il est maintenant temps de créer les étiquettes du cluster !
#
# **Importer des KMeans de SciKit Learn.**

# %% [markdown]
# **Créer une instance d’un modèle K Means avec 2 grappes.**

# %% [markdown]
# **Adapter le modèle à toutes les données, sauf pour la marque de distributeur.**

# %%
# Out:
# KMeans(copy_x=True, init='k-means++', max_iter=300, n_clusters=2, n_init=10,
#     n_jobs=1, precompute_distances='auto', random_state=None, tol=0.0001,
#     verbose=0)

# %% [markdown]
# **Quels sont les vecteurs du centre de la grappe ?**

# %%
# Out:
# array([[  1.81323468e+03,   1.28716592e+03,   4.91044843e+02,
#           2.53094170e+01,   5.34708520e+01,   2.18854858e+03,
#           5.95458894e+02,   1.03957085e+04,   4.31136472e+03,
#           5.41982063e+02,   1.28033632e+03,   7.04424514e+01,
#           7.78251121e+01,   1.40997010e+01,   2.31748879e+01,
#           8.93204634e+03,   6.51195815e+01],
#        [  1.03631389e+04,   6.55089815e+03,   2.56972222e+03,
#           4.14907407e+01,   7.02037037e+01,   1.30619352e+04,
#           2.46486111e+03,   1.07191759e+04,   4.64347222e+03,
#           5.95212963e+02,   1.71420370e+03,   8.63981481e+01,
#           9.13333333e+01,   1.40277778e+01,   2.00740741e+01,
#           1.41705000e+04,   6.75925926e+01]])

# %% [markdown]
# ## Évaluation
#
# Il n’y a pas de moyen parfait d’évaluer le clustering si vous n’avez pas les étiquettes, mais comme ce n’est qu’un exercice, nous avons les étiquettes, alors nous en profitons pour évaluer nos clusters, gardez à l’esprit que vous n’aurez généralement pas ce luxe dans le monde réel.
#
# **Créer une nouvelle colonne pour df appelée « Cluster », qui est un 1 pour une école privée et un 0 pour une école publique.**

# %%
# Out:
#                              Private  Apps  Accept  Enroll  Top10perc  \
# Abilene Christian University     Yes  1660    1232     721         23
# Adelphi University               Yes  2186    1924     512         16
# Adrian College                   Yes  1428    1097     336         22
# Agnes Scott College              Yes   417     349     137         60
# Alaska Pacific University        Yes   193     146      55         16
#
#                               Top25perc  F.Undergrad  P.Undergrad  Outstate  \
# Abilene Christian University         52         2885          537      7440
# Adelphi University                   29         2683         1227     12280
# Adrian College                       50         1036           99     11250
# Agnes Scott College                  89          510           63     12960
# Alaska Pacific University            44          249          869      7560
#
#                               Room.Board  Books  Personal  PhD  Terminal  \
# ...

# %% [markdown]
# **Créer une matrice de confusion et un rapport de classification pour voir comment le regroupement des Kmeans a fonctionné sans que l’on lui attribue d’étiquettes.**

# %%
# Out:
# [[138  74]
#  [531  34]]
#              precision    recall  f1-score   support
#
#           0       0.21      0.65      0.31       212
#           1       0.31      0.06      0.10       565
#
# avg / total       0.29      0.22      0.16       777

# %% [markdown]
# Pas si mal compte tenu que l’algorithme utilise purement les fonctionnalités pour regrouper les universités en 2 groupes distincts! Espérons que vous pouvez commencer à voir comment K Means est utile pour le clustering de données non étiquetées!
